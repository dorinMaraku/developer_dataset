# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
# %matplotlib inline

# %%
df = pd.read_csv('developer_dataset.csv')
df.head()
# Out:
# C:\Users\dmaraku\AppData\Local\Temp\ipykernel_12668\2897537218.py:1: DtypeWarning: Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('developer_dataset.csv')
#    RespondentID  Year        Country          Employment  \
# 0             1  2018  United States  Employed full-time
# 1             1  2019  United States  Employed full-time
# 2             1  2020  United States  Employed full-time
# 3             2  2018  United States  Employed full-time
# 4             2  2019  United States  Employed full-time
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                              DevType  \
# 0           Engineering manager;Full-stack developer
# 1                              Developer, full-stack
# 2                                                NaN
# 3                               Full-stack developer
# 4  Data or business analyst;Database administrato...
#
#                                   LanguageWorkedWith  \
# 0                                                NaN
# 1                                C;C++;C#;Python;SQL
# 2                                  HTML/CSS;Ruby;SQL
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
#
#                               LanguageDesireNextYear  \
# 0                                                NaN
# 1                                C;C#;JavaScript;SQL
# 2                                    Java;Ruby;Scala
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
#
#                                   DatabaseWorkedWith  \
# 0                                                NaN
# 1                                       MySQL;SQLite
# 2                      MySQL;PostgreSQL;Redis;SQLite
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                  Couchbase;DynamoDB;Firebase;MySQL
#
#                               DatabaseDesireNextYear  ...  \
# 0                                                NaN  ...
# 1                                       MySQL;SQLite  ...
# 2                                   MySQL;PostgreSQL  ...
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...  ...
# 4                               Firebase;MySQL;Redis  ...
#
#                               PlatformDesireNextYear Hobbyist  \
# 0                                                NaN      NaN
# 1                                      Linux;Windows       No
# 2  Docker;Google Cloud Platform;Heroku;Linux;Windows      Yes
# 3                                              Azure      NaN
# 4  Android;AWS;Docker;IBM Cloud or Watson;Linux;S...      Yes
#
#                 OrgSize YearsCodePro  \
# 0                   NaN          NaN
# 1  100 to 499 employees          1.0
# 2                   NaN          8.0
# 3                   NaN          4.0
# 4    10 to 19 employees          8.0
#
#                                         JobSeek ConvertedComp  WorkWeekHrs  \
# 0                                           NaN      141000.0          NaN
# 1  I am not interested in new job opportunities       61000.0         80.0
# 2                                           NaN           NaN          NaN
# 3                                           NaN       48000.0          NaN
# 4  I am not interested in new job opportunities       90000.0         40.0
#
#    NEWJobHunt NEWJobHuntResearch     NEWLearn
# 0         NaN                NaN          NaN
# 1         NaN                NaN          NaN
# 2         NaN                NaN  Once a year
# 3         NaN                NaN          NaN
# 4         NaN                NaN          NaN
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['RespondentID', 'Year', 'Country', 'Employment', 'UndergradMajor',
#        'DevType', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'Hobbyist', 'OrgSize', 'YearsCodePro',
#        'JobSeek', 'ConvertedComp', 'WorkWeekHrs', 'NEWJobHunt',
#        'NEWJobHuntResearch', 'NEWLearn'],
#       dtype='object')

# %%
df.count()
# Out:
# RespondentID              111209
# Year                      111209
# Country                   111209
# Employment                109425
# UndergradMajor             98453
# DevType                   100433
# LanguageWorkedWith        102018
# LanguageDesireNextYear     96044
# DatabaseWorkedWith         85859
# DatabaseDesireNextYear     74234
# PlatformWorkedWith         91609
# PlatformDesireNextYear     85376
# Hobbyist                   68352
# OrgSize                    54804
# YearsCodePro               94793
# JobSeek                    60556
# ConvertedComp              91333
# WorkWeekHrs                51089
# NEWJobHunt                 19127
# NEWJobHuntResearch         18683
# NEWLearn                   24226
# dtype: int64

# %%
(df
 ((1-df.count()/df.loc[:,0].count())*100).to_frame()
#  .describe()

)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 (df
# ----> 2  ((1-df.count()/df.loc[:,0].count())*100).to_frame()
#       3 #  .describe()
#       4
#       5 )
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\dmaraku\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 0
